# %%
# !pip install natasha

# %%
from natasha import (
Segmenter,
MorphVocab,

NewsEmbedding,
NewsMorphTagger,
NewsSyntaxParser,
NewsNERTagger, 

PER,
AddrExtractor,

Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = AddrExtractor(morph_vocab)

# %%
from slovnet import NER
from navec import Navec
from tqdm import tqdm
import os
import csv
import re

# text = 'Европейский союз добавил в санкционный список девять политических деятелей из самопровозглашенных республик Донбасса — Донецкой народной республики (ДНР) и Луганской народной республики (ЛНР) — в связи с прошедшими там выборами. Об этом говорится в документе, опубликованном в официальном журнале Евросоюза. В новом списке фигурирует Леонид Пасечник, который по итогам выборов стал главой ЛНР. Помимо него там присутствуют Владимир Бидевка и Денис Мирошниченко, председатели законодательных органов ДНР и ЛНР, а также Ольга Позднякова и Елена Кравченко, председатели ЦИК обеих республик. Выборы прошли в непризнанных республиках Донбасса 11 ноября. На них удержали лидерство действующие руководители и партии — Денис Пушилин и «Донецкая республика» в ДНР и Леонид Пасечник с движением «Мир Луганщине» в ЛНР. Президент Франции Эмманюэль Макрон и канцлер ФРГ Ангела Меркель после встречи с украинским лидером Петром Порошенко осудили проведение выборов, заявив, что они нелегитимны и «подрывают территориальную целостность и суверенитет Украины». Позже к осуждению присоединились США с обещаниями новых санкций для России.'

navec = Navec.load('navec_news_v1_1B_250K_300d_100q.tar')
ner = NER.load('slovnet_ner_news_v1.tar')
ner.navec(navec)

# %%
def get_names_by_slovnet(text):
    return [span for span in ner(text).spans if span.type == 'PER']


def get_names_by_natasha(doc):
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    for token in doc.tokens:
        token.lemmatize(morph_vocab)
    doc.parse_syntax(syntax_parser)
    doc.tag_ner(ner_tagger)
    for span in doc.spans:
        span.normalize(morph_vocab)

    names = []
    for span in doc.spans:
        if span.type == PER:
            names.append(span)
    return names

# %%
import os
from tqdm import tqdm

corpus_dir = './corpus_for_diploma'

filenames_names = {}
for filename in tqdm(os.listdir(corpus_dir)):
    with open(os.path.join(corpus_dir, filename), "r") as f:
        filenames_names[filename] = get_names_by_slovnet(
            re.sub(' +', ' ', re.sub('{\d+?}', '', f.read()))
        )

# %% [markdown]
# import json
#
#
# with open('ner_result.json', 'w') as f:
#     json.dump(filenames_names, f)
#
# # with open('ner_result.json', 'r') as f:
# #     filenames_names = json.load(f)

# %% [markdown]
# for filename in tqdm(os.listdir(corpus_dir)):
#     with open(os.path.join(corpus_dir, filename), "r") as f:
# #         text = f.read()
#         text = re.sub(' +', ' ', re.sub('{\d+?}', '', f.read()))
#         for i, span in enumerate(filenames_names[filename]):
#             filenames_names[filename][i]['text'] = text[span['start']:span['stop']]

# %% [markdown]
#    # Фильтруем имена (оставляем только с фамилией)

# %%
import pymorphy2

morph = pymorphy2.MorphAnalyzer()


def is_with_surn(name_text):
    for name_part in name_text.split():
        normal_form = morph.parse(name_part)[0].normal_form
        for form in morph.parse(normal_form):
            if 'Surn' in form.tag:
                return True
    return False

def get_surn(name_text):
    for name_part in name_text.split():
        normal_form = morph.parse(name_part)[0].normal_form
        for form in morph.parse(normal_form):
            if 'Surn' in form.tag:
                return form.normal_form
    return False

# %%
only_with_fio = {}

for filename in tqdm(os.listdir(corpus_dir)):
    only_with_fio[filename] = []
    for i, span in enumerate(filenames_names[filename]):
        if is_with_surn(span['text']):
            only_with_fio[filename].append(span)
# Out:
# 100%|██████████| 506/506 [00:21<00:00, 23.94it/s]

# %%
with open('only_with_fio.json', 'w') as f:
    json.dump(only_with_fio, f, ensure_ascii=False, indent=3)

# %% [markdown]
# ## Достаем предложения, содержащие упоминания персоналий

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize.punkt import PunktSentenceTokenizer as pt


def get_sentences_with_idx(book_text):
    spans = list(pt().span_tokenize(book_text))
    result = [
        {
            'start': span[0],
            'stop': span[1],
            'sen_text': book_text[span[0]:span[1]]
        }
        for span in spans
    ]
    return result

# %%
filenames_sents = {}

for filename in tqdm(os.listdir(corpus_dir)):
    with open(os.path.join(corpus_dir, filename), "r") as f:
        text = re.sub(' +', ' ', re.sub('{\d+?}', '', f.read()))
        filenames_sents[filename] = get_sentences_with_idx(text)

# %%
def get_sent_by_idx(span, text_sents):
    for sent in text_sents:
        if sent['start'] <= span['start'] and sent['stop'] >= span['stop']:
            return sent

# %%
with_sents = {}
for filename in tqdm(only_with_fio):
    with_sents[filename] = []
    for i, span in enumerate(only_with_fio[filename]):
        sent = get_sent_by_idx(span, filenames_sents[filename])
        if sent:
            span.update({'sentence': sent})
            with_sents[filename].append(span)

# %%
for filename in tqdm(with_sents):
    for i, span in enumerate(with_sents[filename]):
        with_sents[filename][i]['norm_surn'] = get_surn(span['text'])

# %%
with open('with_sents.json', 'w') as f:
    json.dump(with_sents, f, ensure_ascii=False, indent=3)

# %% [markdown]
# ---

# %%
import json
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

with open('with_sents.json', 'r') as f:
    with_sents = json.load(f)

# %%
books_entities = []
for book in with_sents:
    book_entities_ = pd.DataFrame(with_sents[book])
    book_entities_.sentence = book_entities_.sentence.apply(lambda sentence: sentence['sen_text'])
    book_entities_ = book_entities_[['norm_surn', 'sentence']].copy()
    book_entities_['book'] = book
    book_entities_['author'] = book.split('.')[0]  
    books_entities.append(book_entities_)
book_entities = pd.concat(books_entities)
book_entities
# Out:
#    norm_surn                                           sentence  \
# 0   павлищев  -- Да, господин Павлищев, который меня там сод...
# 1    епанчин  -- Да, господин Павлищев, который меня там сод...
# 2    епанчин  -- Узелок ваш все-таки имеет некоторое значени...
# 3    епанчин  -- Узелок ваш все-таки имеет некоторое значени...
# 4   павлищев  Гм... генерала же Епанчина знаем-с, собственно...
# ..       ...                                                ...
# 55       жук                            Жук поместился в ногах.
# 56  дмитриев        Она крепко прижалась к Дмитриевой поддевке.
# 57       жук  Жука некуда было взять; тетя ни за что не позв...
# 58       жук  Бедный Жук лаял, бегал вокруг коляски; Аксюша ...
# 59  зиночкин       Лева наотрез отказался от Зиночкиных конфет.
#
#                                     book              author
# 0                 dostoyevskiy.idiot.txt        dostoyevskiy
# 1                 dostoyevskiy.idiot.txt        dostoyevskiy
# 2                 dostoyevskiy.idiot.txt        dostoyevskiy
# 3                 dostoyevskiy.idiot.txt        dostoyevskiy
# 4                 dostoyevskiy.idiot.txt        dostoyevskiy
# ..                                   ...                 ...
# 55  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova
# 56  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova
# 57  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova
# 58  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova
# 59  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova
#
# [202146 rows x 4 columns]

# %%
norm_surns = book_entities.norm_surn.unique()
len(norm_surns)

# %% [markdown]
# # Сортируем вымышленных от невымышленных

# %%
import wikipedia

wikipedia.set_lang('ru')

# %%
def get_status(name, try_idx_limit=1):
    search_results = wikipedia.search(name)
    if search_results:
        try_idx = 0
        page = None
        while page is None:
            try:
                found_name = search_results[try_idx]
                try:
                    page = wikipedia.page(found_name)
                except wikipedia.DisambiguationError as e:
                    s = random.choice(e.options)
                    page = wikipedia.page(s)
            except:
                try_idx += 1
                if try_idx == try_idx_limit:
                    return None, None, None

        birth_year = None
        for category in page.categories:
            if category.startswith('Категория:Родившиеся в ') and category.endswith('году'):
                birth_year = int(category[23:27])
        return found_name, 'Категория:Персоналии по алфавиту' in page.categories, birth_year
    else:
        return None, None, None

# %%
def filter_names(names):
    filtered_names = []
    for name in tqdm(names):
        found_name, status, birth_year = get_status(name)
        if status and birth_year is not None and birth_year < 1890:
            filtered_names.append([found_name, status, birth_year])
    return filtered_names

# %%
filtered_names = {}

# %%
for name in tqdm(norm_surns):
    found_name, status, birth_year = get_status(name)
    if status and birth_year is not None and birth_year < 1880:
        filtered_names[name] = [found_name, status, birth_year]
# Out:
# 100%|██████████| 229/229 [07:28<00:00,  1.96s/it]

# %% [markdown]
# # Анализ тональности

# %%
import torch
from transformers import AutoModelForSequenceClassification
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained('blanchefort/rubert-base-cased-sentiment-rusentiment')
model = AutoModelForSequenceClassification.from_pretrained('blanchefort/rubert-base-cased-sentiment-rusentiment', return_dict=True)
model.to('cuda')

@torch.no_grad()
def predict(text):
    inputs = tokenizer(text, max_length=512, padding=True, truncation=True, return_tensors='pt')
    inputs.to('cuda')
    outputs = model(**inputs)
    predicted = torch.nn.functional.softmax(outputs.logits, dim=1).detach().cpu()#.numpy()
    predicted = torch.argmax(predicted, dim=1).numpy()
    return predicted[0]

# %%
book_entities['sentiment_class'] = book_entities.sentence.progress_apply(predict)
# Out:
# 100%|██████████| 202146/202146 [25:39<00:00, 131.29it/s]

# %%
book_entities.sentiment_class.value_counts()
# Out:
# 0    184166
# 1     10109
# 2      7871
# Name: sentiment_class, dtype: int64

# %% [markdown]
# # Добавляем метаданные

# %%
import pandas as pd


metadata_df = pd.read_csv('metadata.tsv', sep='\t')
metadata_dict = metadata_df[['filename', 'author', 'title', 'year']].to_dict('records')
metadata_dict = {r['filename']: r for r in metadata_dict}
metadata_dict
# Out:
# {'akhsharumov.kontsy_v_vodu.txt': {'filename': 'akhsharumov.kontsy_v_vodu.txt',
#   'author': 'Ахшарумов, Николай Дмитриевич',
#   'title': 'Концы в воду',
#   'year': 1872},
#  'aksakov.detskiye_gody_bagrova_vnuka.txt': {'filename': 'aksakov.detskiye_gody_bagrova_vnuka.txt',
#   'author': 'Аксаков, Сергей Тимофеевич',
#   'title': 'Детские годы Багрова-внука',
#   'year': 1858},
#  'aksakov.semeynaya_khronika.txt': {'filename': 'aksakov.semeynaya_khronika.txt',
#   'author': 'Аксаков, Сергей Тимофеевич',
#   'title': 'Семейная хроника',
#   'year': 1856},
#  'alekseyev.igra_sudby.txt': {'filename': 'alekseyev.igra_sudby.txt',
#   'author': 'Алексеев, Николай Николаевич',
#   'title': 'Игра судьбы',
#   'year': 1913},
#  'alekseyev.lzhetsarevich.txt': {'filename': 'alekseyev.lzhetsarevich.txt',
#   'author': 'Алексеев, Николай Николаевич',
#   'title': 'Лжецаревич',
#   'year': 1898},
#  'amfiteatrov.otravlennaya_sovest.txt': {'filename': 'amfiteatrov.otravlennaya_sovest.txt',
#   'author': 'Амфитеатров, Александр Валентинович',
#   'title': 'Отравленная совесть',
#   'year': 1890},
#  'annenskaya.anna.txt': {'filename': 'annenskaya.anna.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Анна',
#   'year': 1881},
#  'annenskaya.brat_i_sestra.txt': {'filename': 'annenskaya.brat_i_sestra.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Брат и сестра',
#   'year': 1908},
#  'annenskaya.chuzhoy_khleb.txt': {'filename': 'annenskaya.chuzhoy_khleb.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Чужой хлеб',
#   'year': 1872},
#  'annenskaya.mladshiy_brat.txt': {'filename': 'annenskaya.mladshiy_brat.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Младший брат',
#   'year': 1889},
#  'annenskaya.neudachnik.txt': {'filename': 'annenskaya.neudachnik.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Неудачник',
#   'year': 1889},
#  'annenskaya.trudnaya_borba.txt': {'filename': 'annenskaya.trudnaya_borba.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Трудная борьба',
#   'year': 1889},
#  'annenskaya.tyazhelaya_zhizn.txt': {'filename': 'annenskaya.tyazhelaya_zhizn.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Тяжелая жизнь',
#   'year': 1877},
#  'annenskaya.volchonok.txt': {'filename': 'annenskaya.volchonok.txt',
#   'author': 'Анненская, Александра Никитична',
#   'title': 'Волчонок',
#   'year': 1889},
#  'apraksin.lovkachi.txt': {'filename': 'apraksin.lovkachi.txt',
#   'author': 'Апраксин, Александр  Дмитриевич',
#   'title': 'Ловкачи',
#   'year': 1897},
#  'apukhtin.arkhiv_grafini_d.txt': {'filename': 'apukhtin.arkhiv_grafini_d.txt',
#   'author': 'Апухтин, Алексей Николаевич',
#   'title': 'Архив графини Д.',
#   'year': 1895},
#  'apukhtin.dnevnik_pavlika_dolskogo.txt': {'filename': 'apukhtin.dnevnik_pavlika_dolskogo.txt',
#   'author': 'Апухтин, Алексей Николаевич',
#   'title': 'Дневник Павлика Дольского',
#   'year': 1895},
#  'apukhtin.neokonchennaya_povest.txt': {'filename': 'apukhtin.neokonchennaya_povest.txt',
#   'author': 'Апухтин, Алексей Николаевич',
#   'title': 'Неоконченная повесть',
#   'year': 1898},
#  'askochenskiy.asmodey_nashego_vremeni.txt': {'filename': 'askochenskiy.asmodey_nashego_vremeni.txt',
#   'author': 'Аскоченский, Виктор  Ипатьевич',
#   'title': 'Асмодей нашего времени',
#   'year': 1858},
#  'avdeyev.ivanov.txt': {'filename': 'avdeyev.ivanov.txt',
#   'author': 'Авдеев, Михаил Васильевич',
#   'title': 'Иванов',
#   'year': 1852},
#  'avdeyev.tetrad_iz_zapisok_tamarina.txt': {'filename': 'avdeyev.tetrad_iz_zapisok_tamarina.txt',
#   'author': 'Авдеев, Михаил Васильевич',
#   'title': 'Тетрадь из записок Тамарина',
#   'year': 1852},
#  'avdeyev.varenka.txt': {'filename': 'avdeyev.varenka.txt',
#   'author': 'Авдеев, Михаил Васильевич',
#   'title': 'Варенька',
#   'year': 1852},
#  'avenarius.povetriye.txt': {'filename': 'avenarius.povetriye.txt',
#   'author': 'Авенариус, Василий Петрович',
#   'title': 'Поветрие',
#   'year': 1867},
#  'avenarius.sovremennaya_idilliya.txt': {'filename': 'avenarius.sovremennaya_idilliya.txt',
#   'author': 'Авенариус, Василий Петрович',
#   'title': 'Современная идиллия',
#   'year': 1867},
#  'begichev.semeystvo_kholmskikh.txt': {'filename': 'begichev.semeystvo_kholmskikh.txt',
#   'author': 'Бегичев, Дмитрий Никитич',
#   'title': 'Семейство Холмских. Некоторые черты нравов и образа жизни, семейной и одинокой, русских дворян',
#   'year': 1832},
#  'bestuzhev.russkiy_v_parizhe_1814_goda.txt': {'filename': 'bestuzhev.russkiy_v_parizhe_1814_goda.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Русский в Париже 1814 года',
#   'year': 1834},
#  'bestuzhev_marlinskiy.ammalat_bek.txt': {'filename': 'bestuzhev_marlinskiy.ammalat_bek.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Аммалат-бек',
#   'year': 1834},
#  'bestuzhev_marlinskiy.fregat_nadezhda.txt': {'filename': 'bestuzhev_marlinskiy.fregat_nadezhda.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Фрегат "Надежда"',
#   'year': 1834},
#  'bestuzhev_marlinskiy.ispytaniye.txt': {'filename': 'bestuzhev_marlinskiy.ispytaniye.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Испытание',
#   'year': 1834},
#  'bestuzhev_marlinskiy.leytenant_belozor.txt': {'filename': 'bestuzhev_marlinskiy.leytenant_belozor.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Лейтенант Белозор',
#   'year': 1831},
#  'bestuzhev_marlinskiy.mulla_nur.txt': {'filename': 'bestuzhev_marlinskiy.mulla_nur.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Мулла-нур',
#   'year': 1834},
#  'bestuzhev_marlinskiy.vecher_na_kavkazskikh_vodakh_v_1824_godu.txt': {'filename': 'bestuzhev_marlinskiy.vecher_na_kavkazskikh_vodakh_v_1824_godu.txt',
#   'author': 'Бестужев, Александр  Александрович',
#   'title': 'Вечер на Кавказских водах в 1824 году',
#   'year': 1834},
#  'boborykin.dolgo_li.txt': {'filename': 'boborykin.dolgo_li.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Долго ли',
#   'year': 1876},
#  'boborykin.kitay_gorod.txt': {'filename': 'boborykin.kitay_gorod.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Китай-город',
#   'year': 1883},
#  'boborykin.poumnel.txt': {'filename': 'boborykin.poumnel.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Поумнел',
#   'year': 1897},
#  'boborykin.proyezdom.txt': {'filename': 'boborykin.proyezdom.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Проездом',
#   'year': 1897},
#  'boborykin.vasiliy_terkin.txt': {'filename': 'boborykin.vasiliy_terkin.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Василий Теркин',
#   'year': 1895},
#  'boborykin.zhertva_vechernyaya.txt': {'filename': 'boborykin.zhertva_vechernyaya.txt',
#   'author': 'Боборыкин, Пётр Дмитриевич',
#   'title': 'Жертва вечерняя',
#   'year': 1868},
#  'bulgarin.dimitriy_samozvanets.txt': {'filename': 'bulgarin.dimitriy_samozvanets.txt',
#   'author': 'Булгарин, Фаддей Венедиктович',
#   'title': 'Димитрий Самозванец',
#   'year': 1830},
#  'bulgarin.ivan_petr_ivanovich_vyzhigin.txt': {'filename': 'bulgarin.ivan_petr_ivanovich_vyzhigin.txt',
#   'author': 'Булгарин, Фаддей Венедиктович',
#   'title': 'Иван Иванович Выжигин',
#   'year': 1829},
#  'bulgarin.mazepa.txt': {'filename': 'bulgarin.mazepa.txt',
#   'author': 'Булгарин, Фаддей Венедиктович',
#   'title': 'Мазепа',
#   'year': 1834},
#  'butkov.nevskiy_prospekt_ili_puteshestviya_nestora_zaletayeva.txt': {'filename': 'butkov.nevskiy_prospekt_ili_puteshestviya_nestora_zaletayeva.txt',
#   'author': 'Бутков, Яков  Петрович',
#   'title': 'Невский проспект\xa0или Путешествия Нестора Залетаева',
#   'year': 1848},
#  'chekhov.duel.txt': {'filename': 'chekhov.duel.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Дуэль',
#   'year': 1892},
#  'chekhov.moya_zhizn.txt': {'filename': 'chekhov.moya_zhizn.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Моя жизнь',
#   'year': 1897},
#  'chekhov.palata_no_6.txt': {'filename': 'chekhov.palata_no_6.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Палата No 6',
#   'year': 1894},
#  'chekhov.rasskaz_neizvestnogo_cheloveka.txt': {'filename': 'chekhov.rasskaz_neizvestnogo_cheloveka.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Рассказ неизвестного человека',
#   'year': 1901},
#  'chekhov.step.txt': {'filename': 'chekhov.step.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Степь',
#   'year': 1888},
#  'chekhov.tri_goda.txt': {'filename': 'chekhov.tri_goda.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'Три\xa0года',
#   'year': 1895},
#  'chekhov.v_ovrage.txt': {'filename': 'chekhov.v_ovrage.txt',
#   'author': 'Чехов, Антон Павлович',
#   'title': 'В овраге',
#   'year': 1900},
#  'chernyshevskiy.chto_delat.txt': {'filename': 'chernyshevskiy.chto_delat.txt',
#   'author': 'Чернышевский, Николай Гаврилович',
#   'title': 'Что делать',
#   'year': 1863},
#  'dal.bedovik.txt': {'filename': 'dal.bedovik.txt',
#   'author': 'Даль, Владимир Иванович',
#   'title': 'Бедовик',
#   'year': 1839},
#  'dal.pavel_alekseyevich_igrivyy.txt': {'filename': 'dal.pavel_alekseyevich_igrivyy.txt',
#   'author': 'Даль, Владимир Иванович',
#   'title': 'Павел Алексеевич Игривый',
#   'year': 1861},
#  'dal.pokhozhdeniya_khristiana_khristianovicha.txt': {'filename': 'dal.pokhozhdeniya_khristiana_khristianovicha.txt',
#   'author': 'Даль, Владимир Иванович',
#   'title': 'Похождения Христиана Христиановича Виольдамура и его Аршета',
#   'year': 1844},
#  'dal.vakkh_sidorov_chaykin.txt': {'filename': 'dal.vakkh_sidorov_chaykin.txt',
#   'author': 'Даль, Владимир Иванович',
#   'title': 'Вакх Сидоров Чайкин, или Рассказ его о собственном своем житье-бытье, за первую половину жизни своей',
#   'year': 1861},
#  'danilevskiy.beglyye_v_novorossii.txt': {'filename': 'danilevskiy.beglyye_v_novorossii.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Беглые в Новороссии',
#   'year': 1868},
#  'danilevskiy.beglyye_vorotilis.txt': {'filename': 'danilevskiy.beglyye_vorotilis.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Воля (Беглые воротились)',
#   'year': 1864},
#  'danilevskiy.knyazhna_tarakanova.txt': {'filename': 'danilevskiy.knyazhna_tarakanova.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Княжна Тараканова',
#   'year': 1885},
#  'danilevskiy.mirovich.txt': {'filename': 'danilevskiy.mirovich.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Мирович',
#   'year': 1880},
#  'danilevskiy.potemkin_na_dunaye.txt': {'filename': 'danilevskiy.potemkin_na_dunaye.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Потемкин на Дунае. 1790-й год',
#   'year': 1880},
#  'danilevskiy.sozhzhennaya_moskva.txt': {'filename': 'danilevskiy.sozhzhennaya_moskva.txt',
#   'author': 'Данилевский, Григорий  Петрович',
#   'title': 'Сожженная Москва',
#   'year': 1886},
#  'dmitriyev.dva_imperatora.txt': {'filename': 'dmitriyev.dva_imperatora.txt',
#   'author': 'Дмитриев, Дмитрий Савватиевич',
#   'title': 'Два императора',
#   'year': 1896},
#  'dostoyevskiy.bednyye_lyudi.txt': {'filename': 'dostoyevskiy.bednyye_lyudi.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Бедные люди',
#   'year': 1847},
#  'dostoyevskiy.belyye_nochi.txt': {'filename': 'dostoyevskiy.belyye_nochi.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Белые ночи',
#   'year': 1860},
#  'dostoyevskiy.besy.txt': {'filename': 'dostoyevskiy.besy.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Бесы',
#   'year': 1873},
#  'dostoyevskiy.bratya_karamazovy.txt': {'filename': 'dostoyevskiy.bratya_karamazovy.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Братья Карамазовы',
#   'year': 1881},
#  'dostoyevskiy.dvoynik.txt': {'filename': 'dostoyevskiy.dvoynik.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Двойник',
#   'year': 1846},
#  'dostoyevskiy.dyadyushkin_son.txt': {'filename': 'dostoyevskiy.dyadyushkin_son.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Дядюшкин сон',
#   'year': 1860},
#  'dostoyevskiy.idiot.txt': {'filename': 'dostoyevskiy.idiot.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Идиот',
#   'year': 1874},
#  'dostoyevskiy.igrok.txt': {'filename': 'dostoyevskiy.igrok.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Игрок  (Из записок молодого человека)',
#   'year': 1866},
#  'dostoyevskiy.khozyayka.txt': {'filename': 'dostoyevskiy.khozyayka.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Хозяйка',
#   'year': 1865},
#  'dostoyevskiy.netochka_nezvanova.txt': {'filename': 'dostoyevskiy.netochka_nezvanova.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Неточка Незванова',
#   'year': 1860},
#  'dostoyevskiy.podrostok.txt': {'filename': 'dostoyevskiy.podrostok.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Подросток',
#   'year': 1876},
#  'dostoyevskiy.prestupleniye_i_nakazaniye.txt': {'filename': 'dostoyevskiy.prestupleniye_i_nakazaniye.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Преступление и наказание',
#   'year': 1867},
#  'dostoyevskiy.selo_stepanchikovo_i_yego_obitateli.txt': {'filename': 'dostoyevskiy.selo_stepanchikovo_i_yego_obitateli.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Село Степанчиково и его обитатели',
#   'year': 1860},
#  'dostoyevskiy.unizhennyye_i_oskorblennyye.txt': {'filename': 'dostoyevskiy.unizhennyye_i_oskorblennyye.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Униженные и оскорбленные',
#   'year': 1861},
#  'dostoyevskiy.vechnyy_muzh.txt': {'filename': 'dostoyevskiy.vechnyy_muzh.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Вечный муж',
#   'year': 1871},
#  'dostoyevskiy.zapiski_iz_podpolya.txt': {'filename': 'dostoyevskiy.zapiski_iz_podpolya.txt',
#   'author': 'Достоевский, Фёдор Михайлович',
#   'title': 'Записки из подполья',
#   'year': 1865},
#  'driyanskiy.zapiski_melkotravchatogo.txt': {'filename': 'driyanskiy.zapiski_melkotravchatogo.txt',
#   'author': 'Дриянский, Егор Эдуардович',
#   'title': 'Записки мелкотравчатого',
#   'year': 1859},
#  'druzhinin.obruchennyye.txt': {'filename': 'druzhinin.obruchennyye.txt',
#   'author': 'Дружинин, Александр Васильевич',
#   'title': 'Обрученные',
#   'year': 1857},
#  'druzhinin.polinka_saks.txt': {'filename': 'druzhinin.polinka_saks.txt',
#   'author': 'Дружинин, Александр Васильевич',
#   'title': 'Полинька Сакс',
#   'year': 1847},
#  'druzhinin.rasskaz_alekseya_dmitricha.txt': {'filename': 'druzhinin.rasskaz_alekseya_dmitricha.txt',
#   'author': 'Дружинин, Александр Васильевич',
#   'title': 'Рассказ Алексея Дмитрича',
#   'year': 1865},
#  'durova.gudishki.txt': {'filename': 'durova.gudishki.txt',
#   'author': 'Дурова, Надежда Андреевна',
#   'title': 'Гудишки',
#   'year': 1839},
#  'durova.igra_sudby_ili_protivozakonnaya_lyubov.txt': {'filename': 'durova.igra_sudby_ili_protivozakonnaya_lyubov.txt',
#   'author': 'Дурова, Надежда Андреевна',
#   'title': 'Игра судьбы или Противозаконная любовь',
#   'year': 1837},
#  'durova.pavilon.txt': {'filename': 'durova.pavilon.txt',
#   'author': 'Дурова, Надежда Андреевна',
#   'title': 'Павильон',
#   'year': 1839},
#  'durova.ugol.txt': {'filename': 'durova.ugol.txt',
#   'author': 'Дурова, Надежда Андреевна',
#   'title': 'Угол',
#   'year': 1840},
#  'ertel.dve_pary.txt': {'filename': 'ertel.dve_pary.txt',
#   'author': 'Эртель, Александр Иванович',
#   'title': 'Две пары',
#   'year': 1894},
#  'ertel.gardeniny.txt': {'filename': 'ertel.gardeniny.txt',
#   'author': 'Эртель, Александр Иванович',
#   'title': 'Гарденины, их дворня, приверженцы и враги',
#   'year': 1890},
#  'ertel.karyera_strukova.txt': {'filename': 'ertel.karyera_strukova.txt',
#   'author': 'Эртель, Александр Иванович',
#   'title': 'Карьера Струкова',
#   'year': 1896},
#  'ertel.volkhonskaya_baryshnya.txt': {'filename': 'ertel.volkhonskaya_baryshnya.txt',
#   'author': 'Эртель, Александр Иванович',
#   'title': 'Волхонская барышня',
#   'year': 1883},
#  'filippov.osazhdennyy_sevastopol.txt': {'filename': 'filippov.osazhdennyy_sevastopol.txt',
#   'author': 'Филиппов, Михаил Михайлович',
#   'title': 'Осажденный Севастополь',
#   'year': 1888},
#  'furman.saardamskiy_plotnik.txt': {'filename': 'furman.saardamskiy_plotnik.txt',
#   'author': 'Фурман, Пётр Романович',
#   'title': 'Саардамский плотник',
#   'year': 1847},
#  'gan.ideal.txt': {'filename': 'gan.ideal.txt',
#   'author': 'Ган, Елена Андреевна',
#   'title': 'Идеал',
#   'year': 1837},
#  'gan.sud_sveta.txt': {'filename': 'gan.sud_sveta.txt',
#   'author': 'Ган, Елена Андреевна',
#   'title': 'Суд света',
#   'year': 1843},
#  'garin_mikhaylovskiy.detstvo_tomy.txt': {'filename': 'garin_mikhaylovskiy.detstvo_tomy.txt',
#   'author': 'Гарин-Михайловский, Николай Георгиевич',
#   'title': 'Детство Тёмы',
#   'year': 1893},
#  'garin_mikhaylovskiy.gimnazisty.txt': {'filename': 'garin_mikhaylovskiy.gimnazisty.txt',
#   'author': 'Гарин-Михайловский, Николай Георгиевич',
#   'title': 'Гимназисты',
#   'year': 1895},
#  'garin_mikhaylovskiy.studenty.txt': {'filename': 'garin_mikhaylovskiy.studenty.txt',
#   'author': 'Гарин-Михайловский, Николай Георгиевич',
#   'title': 'Студенты',
#   'year': 1898},
#  'garin_mikhaylovskiy.v_sutoloke_provintsialnoy_zhizni.txt': {'filename': 'garin_mikhaylovskiy.v_sutoloke_provintsialnoy_zhizni.txt',
#   'author': 'Гарин-Михайловский, Николай Георгиевич',
#   'title': 'В сутолоке провинциальной жизни',
#   'year': 1896},
#  'garshin.nadezhda_nikolayevna.txt': {'filename': 'garshin.nadezhda_nikolayevna.txt',
#   'author': 'Гаршин, Всеволод Михайлович',
#   'title': 'Надежда Николаевна',
#   'year': 1888},
#  'gertsen.dolg_prezhde_vsego.txt': {'filename': 'gertsen.dolg_prezhde_vsego.txt',
#   'author': 'Герцен, Александр Иванович',
#   'title': 'Долг прежде всего',
#   'year': 1854},
#  'gertsen.kto_vinovat.txt': {'filename': 'gertsen.kto_vinovat.txt',
#   'author': 'Герцен, Александр Иванович',
#   'title': 'Кто виноват',
#   'year': 1846},
#  'geyntse.arakcheyev.txt': {'filename': 'geyntse.arakcheyev.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Аракчеев',
#   'year': 1893},
#  'geyntse.knyaz_tavridy.txt': {'filename': 'geyntse.knyaz_tavridy.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Князь Тавриды',
#   'year': 1895},
#  'geyntse.koronovannyy_rytsar.txt': {'filename': 'geyntse.koronovannyy_rytsar.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Коронованный рыцарь',
#   'year': 1895},
#  'geyntse.lyudoyedka.txt': {'filename': 'geyntse.lyudoyedka.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Людоедка',
#   'year': 1897},
#  'geyntse.novgorodskaya_volnitsa.txt': {'filename': 'geyntse.novgorodskaya_volnitsa.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Новгородская вольница',
#   'year': 1895},
#  'geyntse.samozvanets.txt': {'filename': 'geyntse.samozvanets.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Самозванец',
#   'year': 1898},
#  'geyntse.stsena_i_zhizn.txt': {'filename': 'geyntse.stsena_i_zhizn.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Сцена и жизнь',
#   'year': 1895},
#  'geyntse.sudnyye_dni_velikogo_novgoroda.txt': {'filename': 'geyntse.sudnyye_dni_velikogo_novgoroda.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Судные дни Великого Новгорода',
#   'year': 1897},
#  'geyntse.tayna_vysokogo_doma.txt': {'filename': 'geyntse.tayna_vysokogo_doma.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'Тайна высокого дома',
#   'year': 1894},
#  'geyntse.v_tine_advokatury.txt': {'filename': 'geyntse.v_tine_advokatury.txt',
#   'author': 'Гейнце, Николай Эдуардович',
#   'title': 'В тине адвокатуры',
#   'year': 1889},
#  'gippius.zlatotsvet.txt': {'filename': 'gippius.zlatotsvet.txt',
#   'author': 'Гиппиус, Зинаида Николаевна',
#   'title': 'Златоцвет',
#   'year': 1896},
#  'glinkav.zadneprovskiya_stseny.txt': {'filename': 'glinkav.zadneprovskiya_stseny.txt',
#   'author': 'Глинка, Василий Сергеевич',
#   'title': 'Заднепровские сцены',
#   'year': 1854},
#  'gogol.mertvyye_dushi.txt': {'filename': 'gogol.mertvyye_dushi.txt',
#   'author': 'Гоголь, Николай Васильевич',
#   'title': 'Мертвые души',
#   'year': 1842},
#  'gogol.portret.txt': {'filename': 'gogol.portret.txt',
#   'author': 'Гоголь, Николай Васильевич',
#   'title': 'Портрет',
#   'year': 1842},
#  'gogol.povest_o_tom_kak_possorilsya_ivan_ivanovich.txt': {'filename': 'gogol.povest_o_tom_kak_possorilsya_ivan_ivanovich.txt',
#   'author': 'Гоголь, Николай Васильевич',
#   'title': 'Повесть о том как поссорился Иван Иванович',
#   'year': 1835},
#  'gogol.starosvetskie_pomeshchiki.txt': {'filename': 'gogol.starosvetskie_pomeshchiki.txt',
#   'author': 'Горький, Максим ',
#   'title': 'Старосветские помещики',
#   'year': 1835},
#  'gogol.taras_bulba.txt': {'filename': 'gogol.taras_bulba.txt',
#   'author': 'Гоголь, Николай Васильевич',
#   'title': 'Тарас Бульба',
#   'year': 1842},
#  'gogol.viy.txt': {'filename': 'gogol.viy.txt',
#   'author': 'Горький, Максим ',
#   'title': 'Вий',
#   'year': 1835},
#  'goncharov.oblomov.txt': {'filename': 'goncharov.oblomov.txt',
#   'author': 'Гончаров, Иван Александрович',
#   'title': 'Обломов',
#   'year': 1859},
#  'goncharov.obryv.txt': {'filename': 'goncharov.obryv.txt',
#   'author': 'Гончаров, Иван Александрович',
#   'title': 'Обрыв',
#   'year': 1870},
#  'goncharov.obyknovennaya_istoriya.txt': {'filename': 'goncharov.obyknovennaya_istoriya.txt',
#   'author': 'Гончаров, Иван Александрович',
#   'title': 'Обыкновенная история',
#   'year': 1847},
#  'gorkiy.foma_gordeyev.txt': {'filename': 'gorkiy.foma_gordeyev.txt',
#   'author': 'Горький, Максим ',
#   'title': 'Фома Гордеев',
#   'year': 1900},
#  'gorkiy.konovalov.txt': {'filename': 'gorkiy.konovalov.txt',
#   'author': 'Горький, Максим ',
#   'title': 'Коновалов',
#   'year': 1897},
#  'grebenka.chaykovskiy.txt': {'filename': 'grebenka.chaykovskiy.txt',
#   'author': 'Гребенка, Евгений Павлович',
#   'title': 'Чайковский',
#   'year': 1848},
#  'grech.chernaya_zhenshchina.txt': {'filename': 'grech.chernaya_zhenshchina.txt',
#   'author': 'Греч, Николай Иванович',
#   'title': 'Черная женщина',
#   'year': 1834},
#  'grigorovich.anton_goremyka.txt': {'filename': 'grigorovich.anton_goremyka.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Антон Горемыка',
#   'year': 1872},
#  'grigorovich.derevnya.txt': {'filename': 'grigorovich.derevnya.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Деревня',
#   'year': 1859},
#  'grigorovich.dva_generala.txt': {'filename': 'grigorovich.dva_generala.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Два генерала',
#   'year': 1864},
#  'grigorovich.koshka_i_myshka.txt': {'filename': 'grigorovich.koshka_i_myshka.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Кошка и мышка',
#   'year': 1859},
#  'grigorovich.neudavshayasya_zhizn.txt': {'filename': 'grigorovich.neudavshayasya_zhizn.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Неудавшаяся жизнь',
#   'year': 1850},
#  'grigorovich.pakhotnik_i_barkhatnik.txt': {'filename': 'grigorovich.pakhotnik_i_barkhatnik.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Пахотник и бархатник',
#   'year': 1872},
#  'grigorovich.pereselentsy.txt': {'filename': 'grigorovich.pereselentsy.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Переселенцы',
#   'year': 1857},
#  'grigorovich.rybaki.txt': {'filename': 'grigorovich.rybaki.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Рыбаки',
#   'year': 1853},
#  'grigorovich.svistulkin.txt': {'filename': 'grigorovich.svistulkin.txt',
#   'author': 'Григорович, Дмитрий  Васильевич',
#   'title': 'Свистулькин',
#   'year': 1859},
#  'iogel.mezhdu_vechnostyu_i_minutoy.txt': {'filename': 'iogel.mezhdu_vechnostyu_i_minutoy.txt',
#   'author': 'Иогель, Михаил Константинович',
#   'title': 'Между вечностью и минутой',
#   'year': 1881},
#  'kalashnikov.kamchadalka.txt': {'filename': 'kalashnikov.kamchadalka.txt',
#   'author': 'Калашников, Иван Тимофеевич',
#   'title': 'Камчадалка',
#   'year': 1842},
#  'karnovich.lyubov_i_korona.txt': {'filename': 'karnovich.lyubov_i_korona.txt',
#   'author': 'Карнович, Евгений Петрович',
#   'title': 'Любовь и корона: Ист. роман из времен императрицы Анны Иоановны и регентства принцессы Анны Леопольдовны',
#   'year': 1879},
#  'karnovich.na_vysote_i_na_dole_tsarevna_sofya_alekseyevna.txt': {'filename': 'karnovich.na_vysote_i_na_dole_tsarevna_sofya_alekseyevna.txt',
#   'author': 'Карнович, Евгений Петрович',
#   'title': 'На высоте и на доле: Царевна Софья Алексеевна',
#   'year': 1897},
#  'karnovich.pridvornoye_kruzhevo.txt': {'filename': 'karnovich.pridvornoye_kruzhevo.txt',
#   'author': 'Карнович, Евгений Петрович',
#   'title': 'Придворное кружево',
#   'year': 1885},
#  'khomyakov.svetloye_voskresenye.txt': {'filename': 'khomyakov.svetloye_voskresenye.txt',
#   'author': 'Хомяков, Алексей Степанович',
#   'title': 'Светлое Воскресенье',
#   'year': 1900},
#  'khvoshchinskaya.bratets.txt': {'filename': 'khvoshchinskaya.bratets.txt',
#   'author': 'Хвощинская (Зайончковская), Надежда Дмитриевна',
#   'title': 'Братец',
#   'year': 1858},
#  'khvoshchinskaya.pansionerka.txt': {'filename': 'khvoshchinskaya.pansionerka.txt',
#   'author': 'Хвощинская (Зайончковская), Надежда Дмитриевна',
#   'title': 'Пансионерка',
#   'year': 1861},
#  'khvoshchinskaya.pervaya_borba.txt': {'filename': 'khvoshchinskaya.pervaya_borba.txt',
#   'author': 'Хвощинская (Зайончковская), Надежда Дмитриевна',
#   'title': 'Первая борьба',
#   'year': 1879},
#  'kogan.v_glukhom_mestechke.txt': {'filename': 'kogan.v_glukhom_mestechke.txt',
#   'author': 'Коган, Наум Львович',
#   'title': 'В глухом местечке',
#   'year': 1894},
#  'kokhanovskaya.gayka.txt': {'filename': 'kokhanovskaya.gayka.txt',
#   'author': 'Кохановская, Надежда Степановна',
#   'title': 'Гайка',
#   'year': 1860},
#  'kokhanovskaya.iz_provintsialnoy_galerei_portretov.txt': {'filename': 'kokhanovskaya.iz_provintsialnoy_galerei_portretov.txt',
#   'author': 'Кохановская, Надежда Степановна',
#   'title': 'Из провинциальной галереи портретов',
#   'year': 1863},
#  'kokhanovskaya.lyubila.txt': {'filename': 'kokhanovskaya.lyubila.txt',
#   'author': 'Кохановская, Надежда Степановна',
#   'title': 'Любила',
#   'year': 1858},
#  'kokorev.savvushka.txt': {'filename': 'kokorev.savvushka.txt',
#   'author': 'Кокорев, Иван Тимофеевич',
#   'title': 'Саввушка',
#   'year': 1852},
#  'kokorev.sibirka.txt': {'filename': 'kokorev.sibirka.txt',
#   'author': 'Кокорев, Иван Тимофеевич',
#   'title': 'Сибирка',
#   'year': 1847},
#  'kolbasin.akademicheskiy_pereulok.txt': {'filename': 'kolbasin.akademicheskiy_pereulok.txt',
#   'author': 'Колбасин, Елисей Яковлевич',
#   'title': 'Академический переулок',
#   'year': 1858},
#  'konshin.graf_oboyanskiy_ili_smolensk_v_1812_godu.txt': {'filename': 'konshin.graf_oboyanskiy_ili_smolensk_v_1812_godu.txt',
#   'author': 'Колбасин, Елисей Яковлевич',
#   'title': 'Граф Обоянский или Смоленск в 1812 году',
#   'year': 1834},
#  'kornilovich.andrey_bezymennyy.txt': {'filename': 'kornilovich.andrey_bezymennyy.txt',
#   'author': 'Корнилович, Александр Осипович',
#   'title': 'Андрей Безыменный',
#   'year': 1832},
#  'korolenko.bez_yazyka.txt': {'filename': 'korolenko.bez_yazyka.txt',
#   'author': 'Короленко, Владимир Галактионович',
#   'title': 'Без языка',
#   'year': 1902},
#  'korolenko.marusina_zaimka.txt': {'filename': 'korolenko.marusina_zaimka.txt',
#   'author': 'Короленко, Владимир Галактионович',
#   'title': 'Марусина заимка',
#   'year': 1905},
#  'korolenko.slepoy_muzykant.txt': {'filename': 'korolenko.slepoy_muzykant.txt',
#   'author': 'Короленко, Владимир Галактионович',
#   'title': 'Слепой музыкант',
#   'year': 1888},
#  'korolenko.sudnyy_den_iom_kipur.txt': {'filename': 'korolenko.sudnyy_den_iom_kipur.txt',
#   'author': 'Короленко, Владимир Галактионович',
#   'title': 'Судный день (Иом-кипур)',
#   'year': 1903},
#  'korolenko.v_durnom_obshchestve.txt': {'filename': 'korolenko.v_durnom_obshchestve.txt',
#   'author': 'Короленко, Владимир Галактионович',
#   'title': 'В дурном обществе',
#   'year': 1894},
#  'krasnitskiy.groza_vizantii.txt': {'filename': 'krasnitskiy.groza_vizantii.txt',
#   'author': 'Красницкий, Александр Иванович',
#   'title': 'Гроза Византии',
#   'year': 1898},
#  'krasnitskiy.knyaz_svyatoslav.txt': {'filename': 'krasnitskiy.knyaz_svyatoslav.txt',
#   'author': 'Красницкий, Александр Иванович',
#   'title': 'Князь Святослав',
#   'year': 1894},
#  'krasnitskiy.krasnoye_solnyshko.txt': {'filename': 'krasnitskiy.krasnoye_solnyshko.txt',
#   'author': 'Красницкий, Александр Иванович',
#   'title': 'Красное Солнышко',
#   'year': 1902},
#  'krasnova.ne_sudba.txt': {'filename': 'krasnova.ne_sudba.txt',
#   'author': 'Краснова (Бекетова), Екатерина Андреевна',
#   'title': 'Не судьба',
#   'year': 1881},
#  'krestovskaya.ranniye_grozy.txt': {'filename': 'krestovskaya.ranniye_grozy.txt',
#   'author': 'Крестовская (Картавцева), Мария Сергеевна',
#   'title': 'Ранние грозы',
#   'year': 1889},
#  'krestovskaya.vopl.txt': {'filename': 'krestovskaya.vopl.txt',
#   'author': 'Крестовская (Картавцева), Мария Сергеевна',
#   'title': 'Вопль',
#   'year': 1903},
#  'kryukov.na_tikhom_donu.txt': {'filename': 'kryukov.na_tikhom_donu.txt',
#   'author': 'Крюков, Фёдор Дмитриевич',
#   'title': 'На тихом Дону',
#   'year': 1898},
#  'kryzhanovskaya.dva_sfinksa.txt': {'filename': 'kryzhanovskaya.dva_sfinksa.txt',
#   'author': 'Семёнова (Крыжановская), Вера Ивановна',
#   'title': 'Два сфинкса',
#   'year': 1900},
#  'kryzhanovskaya.mest_yevreya.txt': {'filename': 'kryzhanovskaya.mest_yevreya.txt',
#   'author': 'Семёнова (Крыжановская), Вера Ивановна',
#   'title': 'Месть еврея',
#   'year': 1892},
#  'kryzhanovskaya.rekenshteyny.txt': {'filename': 'kryzhanovskaya.rekenshteyny.txt',
#   'author': 'Семёнова (Крыжановская), Вера Ивановна',
#   'title': 'Рекенштейны',
#   'year': 1894},
#  'kryzhanovskaya.tsaritsa_khatasu.txt': {'filename': 'kryzhanovskaya.tsaritsa_khatasu.txt',
#   'author': 'Семёнова (Крыжановская), Вера Ивановна',
#   'title': 'Царица Хатасу',
#   'year': 1894},
#  'kryzhanovskaya.zakoldovannyy_zamok.txt': {'filename': 'kryzhanovskaya.zakoldovannyy_zamok.txt',
#   'author': 'Семёнова (Крыжановская), Вера Ивановна',
#   'title': 'Заколдованный замок',
#   'year': 1898},
#  'kugushev.kornet_otletayev.txt': {'filename': 'kugushev.kornet_otletayev.txt',
#   'author': 'Кугушев, Григорий Васильевич',
#   'title': 'Корнет Отлетаев',
#   'year': 1856},
#  'kulchitskiy.neobyknovennyy_poyedinok.txt': {'filename': 'kulchitskiy.neobyknovennyy_poyedinok.txt',
#   'author': 'Кульчицкий, Александр Яковлевич',
#   'title': 'Необыкновенный поединок',
#   'year': 1845},
#  'kuprin.molokh.txt': {'filename': 'kuprin.molokh.txt',
#   'author': 'Куприн, Александр Иванович',
#   'title': 'Молох',
#   'year': 1903},
#  'kuprin.na_perelome.txt': {'filename': 'kuprin.na_perelome.txt',
#   'author': 'Куприн, Александр Иванович',
#   'title': 'На переломе',
#   'year': 1908},
#  'kuprin.olesya.txt': {'filename': 'kuprin.olesya.txt',
#   'author': 'Куприн, Александр Иванович',
#   'title': 'Олеся',
#   'year': 1905},
#  'kuprin.vpotmakh.txt': {'filename': 'kuprin.vpotmakh.txt',
#   'author': 'Куприн, Александр Иванович',
#   'title': 'Впотьмах',
#   'year': 1912},
#  'kushchevskiy.nikolay_negorev_ili_blagopoluchnyy_rossiyanin.txt': {'filename': 'kushchevskiy.nikolay_negorev_ili_blagopoluchnyy_rossiyanin.txt',
#   'author': 'Кущевский, Иван Афанасьевич',
#   'title': 'Николай Негорев или Благополучный россиянин',
#   'year': 1872},
#  'lazhechnikov.basurman.txt': {'filename': 'lazhechnikov.basurman.txt',
#   'author': 'Лажечников, Иван Иванович',
#   'title': 'Басурман',
#   'year': 1838},
#  'lazhechnikov.belenkiye_chernenkiye_i_serenkiye.txt': {'filename': 'lazhechnikov.belenkiye_chernenkiye_i_serenkiye.txt',
#   'author': 'Лажечников, Иван Иванович',
#   'title': 'Беленькие, черненькие, и серенькие',
#   'year': 1858},
#  'lazhechnikov.ledyanoy_dom.txt': {'filename': 'lazhechnikov.ledyanoy_dom.txt',
#   'author': 'Лажечников, Иван Иванович',
#   'title': 'Ледяной дом',
#   'year': 1835},
#  'lazhechnikov.posledniy_novik_ili_zavoyevaniye_liflyandii.txt': {'filename': 'lazhechnikov.posledniy_novik_ili_zavoyevaniye_liflyandii.txt',
#   'author': 'Лажечников, Иван Иванович',
#   'title': 'Последний Новик или Завоевание Лифляндии',
#   'year': 1833},
#  'lazhechnikov.vnuchka_pantsirnogo_boyarina.txt': {'filename': 'lazhechnikov.vnuchka_pantsirnogo_boyarina.txt',
#   'author': 'Лажечников, Иван Иванович',
#   'title': 'Внучка панцирного боярина',
#   'year': 1868},
#  'lebedev.za_svyatuyu_obitel.txt': {'filename': 'lebedev.za_svyatuyu_obitel.txt',
#   'author': 'Лебедев, Владимир Петрович',
#   'title': 'За\xa0святую обитель',
#   'year': 1900},
#  'leontyev.aspaziya_lampridi.txt': {'filename': 'leontyev.aspaziya_lampridi.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Аспазия Ламприди',
#   'year': 1876},
#  'leontyev.ditya_dushi.txt': {'filename': 'leontyev.ditya_dushi.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Дитя души',
#   'year': 1876},
#  'leontyev.ispoved_muzha_ay_burun.txt': {'filename': 'leontyev.ispoved_muzha_ay_burun.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Исповедь мужа (Ай-Бурун)',
#   'year': 1867},
#  'leontyev.khrizo.txt': {'filename': 'leontyev.khrizo.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Хризо',
#   'year': 1876},
#  'leontyev.leto_na_khutore.txt': {'filename': 'leontyev.leto_na_khutore.txt',
#   'author': 'Высоцкой, Д. Д.',
#   'title': 'Лето на хуторе',
#   'year': 1855},
#  'leontyev.pembe.txt': {'filename': 'leontyev.pembe.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Пембе',
#   'year': 1870},
#  'leontyev.sfakiot.txt': {'filename': 'leontyev.sfakiot.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Сфакиот',
#   'year': 1877},
#  'leontyev.v_svoyem_krayu.txt': {'filename': 'leontyev.v_svoyem_krayu.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'В своем краю',
#   'year': 1864},
#  'leontyev.yegipetskiy_golub.txt': {'filename': 'leontyev.yegipetskiy_golub.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Египетский голубь',
#   'year': 1881},
#  'leontyev_shcheglov.kordeliya.txt': {'filename': 'leontyev_shcheglov.kordeliya.txt',
#   'author': 'Леонтьев, Константин Николаевич',
#   'title': 'Корделия',
#   'year': 1891},
#  'lermontov.geroy_nashego_vremeni.txt': {'filename': 'lermontov.geroy_nashego_vremeni.txt',
#   'author': 'Лермонтов, Михаил Юрьевич',
#   'title': 'Герой нашего времени',
#   'year': 1840},
#  'lermontov.knyaginya_ligovskaya.txt': {'filename': 'lermontov.knyaginya_ligovskaya.txt',
#   'author': 'Лермонтов, Михаил Юрьевич',
#   'title': 'Княгиня Лиговская',
#   'year': 1891},
#  'lermontov.vadim.txt': {'filename': 'lermontov.vadim.txt',
#   'author': 'Лермонтов, Михаил Юрьевич',
#   'title': 'Вадим',
#   'year': 1873},
#  'leskov._kolyvanskiy_muzh.txt': {'filename': 'leskov._kolyvanskiy_muzh.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Колыванский муж',
#   'year': 1888},
#  'leskov.askalonskiy_zlodey.txt': {'filename': 'leskov.askalonskiy_zlodey.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Аскалонский злодей',
#   'year': 1889},
#  'leskov.chortovy_kukly.txt': {'filename': 'leskov.chortovy_kukly.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Чёртовы куклы',
#   'year': 1890},
#  'leskov.detskiye_gody.txt': {'filename': 'leskov.detskiye_gody.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Детские годы',
#   'year': 1876},
#  'leskov.interesnyye_muzhchiny.txt': {'filename': 'leskov.interesnyye_muzhchiny.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Интересные мужчины',
#   'year': 1886},
#  'leskov.ledi_makbet_mtsenskogo_uyezda.txt': {'filename': 'leskov.ledi_makbet_mtsenskogo_uyezda.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Леди Макбет Мценского уезда',
#   'year': 1889},
#  'leskov.na_krayu_sveta.txt': {'filename': 'leskov.na_krayu_sveta.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'На краю света',
#   'year': 1876},
#  'leskov.na_nozhakh.txt': {'filename': 'leskov.na_nozhakh.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'На ножах',
#   'year': 1871},
#  'leskov.nekuda.txt': {'filename': 'leskov.nekuda.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Некуда',
#   'year': 1865},
#  'leskov.oboydennyye.txt': {'filename': 'leskov.oboydennyye.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Обойденные',
#   'year': 1866},
#  'leskov.ocharovannyy_strannik.txt': {'filename': 'leskov.ocharovannyy_strannik.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Очарованный странник',
#   'year': 1874},
#  'leskov.oskorblennaya_neteta.txt': {'filename': 'leskov.oskorblennaya_neteta.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Оскорбленная Нетэта',
#   'year': 1917},
#  'leskov.ostrovityane.txt': {'filename': 'leskov.ostrovityane.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Островитяне',
#   'year': 1866},
#  'leskov.pavlin.txt': {'filename': 'leskov.pavlin.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Павлин',
#   'year': 1876},
#  'leskov.pecherskiye_antiki.txt': {'filename': 'leskov.pecherskiye_antiki.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Печерские антики',
#   'year': 1883},
#  'leskov.polunoshchniki.txt': {'filename': 'leskov.polunoshchniki.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Полунощники',
#   'year': 1893},
#  'leskov.smekh_i_gore.txt': {'filename': 'leskov.smekh_i_gore.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Смех и горе',
#   'year': 1871},
#  'leskov.soboryane.txt': {'filename': 'leskov.soboryane.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Соборяне',
#   'year': 1872},
#  'leskov.staryye_gody_v_sele_plodomasove.txt': {'filename': 'leskov.staryye_gody_v_sele_plodomasove.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Старые годы в селе Плодомасове',
#   'year': 1888},
#  'leskov.voitelnitsa.txt': {'filename': 'leskov.voitelnitsa.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Воительница',
#   'year': 1873},
#  'leskov.zagadochnyy_chelovek.txt': {'filename': 'leskov.zagadochnyy_chelovek.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Загадочный человек',
#   'year': 1871},
#  'leskov.zakhudalyy_rod.txt': {'filename': 'leskov.zakhudalyy_rod.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Захудалый род',
#   'year': 1875},
#  'leskov.zapechatlennyy_angel.txt': {'filename': 'leskov.zapechatlennyy_angel.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Запечатленный ангел',
#   'year': 1874},
#  'leskov.zayachiy_remiz.txt': {'filename': 'leskov.zayachiy_remiz.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Заячий ремиз',
#   'year': 1922},
#  'leskov.zheleznaya_volya.txt': {'filename': 'leskov.zheleznaya_volya.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Железная воля',
#   'year': 1876},
#  'leskov.zhitiye_odnoy_baby.txt': {'filename': 'leskov.zhitiye_odnoy_baby.txt',
#   'author': 'Лесков, Николай Семёнович',
#   'title': 'Житие одной бабы',
#   'year': 1863},
#  'levitov.nakanune_khristova_dnya.txt': {'filename': 'levitov.nakanune_khristova_dnya.txt',
#   'author': 'Левитов, Александр Иванович',
#   'title': 'Накануне Христова дня',
#   'year': 1861},
#  'leykin.aktery_lyubiteli.txt': {'filename': 'leykin.aktery_lyubiteli.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'Актеры-любители',
#   'year': 1891},
#  'leykin.dva_sopernika.txt': {'filename': 'leykin.dva_sopernika.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'Два соперника',
#   'year': 1891},
#  'leykin.gde_apelsiny_zreyut.txt': {'filename': 'leykin.gde_apelsiny_zreyut.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'Где апельсины зреют. Юморист. описание путешествия супругов Николая Ивановича и Глафиры Семеновны Ивановых по Ривьере и Италии',
#   'year': 1893},
#  'leykin.na_zarabotkakh.txt': {'filename': 'leykin.na_zarabotkakh.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'На заработках',
#   'year': 1892},
#  'leykin.nashi_zagranitsey.txt': {'filename': 'leykin.nashi_zagranitsey.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'Наши заграницей',
#   'year': 1892},
#  'leykin.v_gostyakh_u_turok.txt': {'filename': 'leykin.v_gostyakh_u_turok.txt',
#   'author': 'Лейкин, Николай Александрович',
#   'title': 'В гостях у турок: Юмористическое описание путешествия супругов Николая Ивановича и Глафиры Семеновны Ивановых через Славянские земли в Константинополь',
#   'year': 1897},
#  'linev.po_tyurmam.txt': {'filename': 'linev.po_tyurmam.txt',
#   'author': 'Линев, Дмитрий Александрович',
#   'title': 'Пo тюрьмам',
#   'year': 1878},
#  'lukhmanova.devochki.txt': {'filename': 'lukhmanova.devochki.txt',
#   'author': 'Лухманова (Байкова), Надежда Александровна',
#   'title': 'Девочки',
#   'year': 1896},
#  'machtet.v_tundre_i_v_tayge.txt': {'filename': 'machtet.v_tundre_i_v_tayge.txt',
#   'author': 'Мачтет, Григорий Александрович',
#   'title': 'В тундре и в тайге',
#   'year': 1893},
#  'maklakova_nelidova.devochka_lida.txt': {'filename': 'maklakova_nelidova.devochka_lida.txt',
#   'author': 'Маклакова (Королёва), Лидия Филипповна',
#   'title': 'Девочка Лида',
#   'year': 1875},
#  'maksimov.sibir_i_katorga.txt': {'filename': 'maksimov.sibir_i_katorga.txt',
#   'author': 'Максимов, Сергей Васильевич',
#   'title': 'Сибирь и каторга',
#   'year': 1862},
#  'mamin_sibiryak.boytsy.txt': {'filename': 'mamin_sibiryak.boytsy.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Бойцы',
#   'year': 1889},
#  'mamin_sibiryak.bratya_gordeyevy.txt': {'filename': 'mamin_sibiryak.bratya_gordeyevy.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Братья Гордеевы',
#   'year': 1896},
#  'mamin_sibiryak.cherty_iz_zhizni_pepko.txt': {'filename': 'mamin_sibiryak.cherty_iz_zhizni_pepko.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Черты из жизни Пепко',
#   'year': 1895},
#  'mamin_sibiryak.gornoye_gnezdo.txt': {'filename': 'mamin_sibiryak.gornoye_gnezdo.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Горное гнездо',
#   'year': 1890},
#  'mamin_sibiryak.imeninnik.txt': {'filename': 'mamin_sibiryak.imeninnik.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Именинник',
#   'year': 1888},
#  'mamin_sibiryak.khleb.txt': {'filename': 'mamin_sibiryak.khleb.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Хлеб',
#   'year': 1896},
#  'mamin_sibiryak.na_rubezhe_azii.txt': {'filename': 'mamin_sibiryak.na_rubezhe_azii.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'На рубеже Азии',
#   'year': 1882},
#  'mamin_sibiryak.okhoniny_brovi.txt': {'filename': 'mamin_sibiryak.okhoniny_brovi.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Охонины брови',
#   'year': 1896},
#  'mamin_sibiryak.privalovskiye_milliony.txt': {'filename': 'mamin_sibiryak.privalovskiye_milliony.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Приваловские миллионы',
#   'year': 1897},
#  'mamin_sibiryak.sestry.txt': {'filename': 'mamin_sibiryak.sestry.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Сестры',
#   'year': 1883},
#  'mamin_sibiryak.tri_kontsa.txt': {'filename': 'mamin_sibiryak.tri_kontsa.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Три конца',
#   'year': 1895},
#  'mamin_sibiryak.v_gorakh.txt': {'filename': 'mamin_sibiryak.v_gorakh.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'В горах',
#   'year': 1898},
#  'mamin_sibiryak.vernyy_rab.txt': {'filename': 'mamin_sibiryak.vernyy_rab.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Верный раб',
#   'year': 1901},
#  'mamin_sibiryak.vesenniye_grozy.txt': {'filename': 'mamin_sibiryak.vesenniye_grozy.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Весенние грозы',
#   'year': 1895},
#  'mamin_sibiryak.zoloto.txt': {'filename': 'mamin_sibiryak.zoloto.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Золото',
#   'year': 1895},
#  'mamin_sibiryak.zolotukha.txt': {'filename': 'mamin_sibiryak.zolotukha.txt',
#   'author': 'Мамин-Сибиряк, Дмитрий ',
#   'title': 'Золотуха',
#   'year': 1889},
#  'markevich.bezdna.txt': {'filename': 'markevich.bezdna.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Бездна',
#   'year': 1884},
#  'markevich.dve_maski.txt': {'filename': 'markevich.dve_maski.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Две маски',
#   'year': 1874},
#  'markevich.knyazhna_tata.txt': {'filename': 'markevich.knyazhna_tata.txt',
#   'author': 'Бем, Мери ',
#   'title': 'Княжна Тата',
#   'year': 1879},
#  'markevich.lesnik.txt': {'filename': 'markevich.lesnik.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Лесник',
#   'year': 1880},
#  'markevich.marina_iz_alago_roga.txt': {'filename': 'markevich.marina_iz_alago_roga.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Марина из Алого Рога',
#   'year': 1873},
#  'markevich.tipy_proshlago.txt': {'filename': 'markevich.tipy_proshlago.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Типы прошлого',
#   'year': 1868},
#  'markevich.zabytyy_vopros.txt': {'filename': 'markevich.zabytyy_vopros.txt',
#   'author': 'Маркевич, Болеслав Михайлович',
#   'title': 'Забытый вопрос',
#   'year': 1872},
#  'masalskiy.chernyy_yashchik.txt': {'filename': 'masalskiy.chernyy_yashchik.txt',
#   'author': 'Масальский, Константин Петрович',
#   'title': 'Черный ящик',
#   'year': 1833},
#  'masalskiy.osada_uglicha.txt': {'filename': 'masalskiy.osada_uglicha.txt',
#   'author': 'Масальский, Константин Петрович',
#   'title': 'Осада Углича',
#   'year': 1841},
#  'masalskiy.regentstvo_birona.txt': {'filename': 'masalskiy.regentstvo_birona.txt',
#   'author': 'Масальский, Константин Петрович',
#   'title': 'Регентство Бирона',
#   'year': 1834},
#  'masalskiy.streltsy.txt': {'filename': 'masalskiy.streltsy.txt',
#   'author': 'Масальский, Константин Петрович',
#   'title': 'Стрельцы',
#   'year': 1832},
#  'melnikov.na_gorakh.txt': {'filename': 'melnikov.na_gorakh.txt',
#   'author': 'Мельников-Печерский, Павел Иванович',
#   'title': 'На горах',
#   'year': 1826},
#  'melnikov.staryye_gody.txt': {'filename': 'melnikov.staryye_gody.txt',
#   'author': 'Мельников-Печерский, Павел Иванович',
#   'title': 'Старые годы',
#   'year': 1876},
#  'melnikov.v_lesakh.txt': {'filename': 'melnikov.v_lesakh.txt',
#   'author': 'Мельников-Печерский, Павел Иванович',
#   'title': 'В лесах',
#   'year': 1826},
#  'menshikov.dieta_dushi.txt': {'filename': 'menshikov.dieta_dushi.txt',
#   'author': 'Меньшиков, Михаил Осипович',
#   'title': 'Диета души',
#   'year': 1861},
#  'merder.avantyuristy.txt': {'filename': 'merder.avantyuristy.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Авантюристы',
#   'year': 1915},
#  'merder.pered_razgromom.txt': {'filename': 'merder.pered_razgromom.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Перед разгромом',
#   'year': 1904},
#  'merder.posledniy_iz_vorotyntsevykh.txt': {'filename': 'merder.posledniy_iz_vorotyntsevykh.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Последний из Воротынцевых',
#   'year': 1896},
#  'merder.taynyy_brak.txt': {'filename': 'merder.taynyy_brak.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Тайный брак',
#   'year': 1910},
#  'merder.tsarskiy_prikaz.txt': {'filename': 'merder.tsarskiy_prikaz.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Царский приказ',
#   'year': 1915},
#  'merder.v_poiskakh_istiny.txt': {'filename': 'merder.v_poiskakh_istiny.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'В поисках истины',
#   'year': 1895},
#  'merder.vorotyntsevy.txt': {'filename': 'merder.vorotyntsevy.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Воротынцевы',
#   'year': 1891},
#  'merder.zvezda_tsesarevny.txt': {'filename': 'merder.zvezda_tsesarevny.txt',
#   'author': 'Мердер, Надежда Ивановна',
#   'title': 'Звезда цесаревны',
#   'year': 1906},
#  'mikhaylov.adam_adamych.txt': {'filename': 'mikhaylov.adam_adamych.txt',
#   'author': 'Михайлов, Михаил Ларионович',
#   'title': 'Адам Адамыч',
#   'year': 1859},
#  'mordovtsev.derzhavnyy_plotnik.txt': {'filename': 'mordovtsev.derzhavnyy_plotnik.txt',
#   'author': 'Мордовцев, Даниил Лукич',
#   'title': 'Державный плотник',
#   'year': 1899},
#  'mordovtsev.dvenadtsatyy_god.txt': {'filename': 'mordovtsev.dvenadtsatyy_god.txt',
#   'author': 'Мордовцев, Даниил Лукич',
#   'title': 'Двенадцатый год',
#   'year': 1901},
#  'mordovtsev.fanatik.txt': {'filename': 'mordovtsev.fanatik.txt',
#   'author': 'Мордовцев, Даниил Лукич',
#   'title': 'Фанатик',
#   'year': 1891},
#  'mordovtsev.gospodin_velikiy_novgorod.txt': {'filename': 'mordovtsev.gospodin_velikiy_novgorod.txt',
#   'author': 'Мордовцев, Даниил Лукич',
#   'title': 'Господин Великий Новгород',
#   'year': 1882},
# ...
#   'title': 'История одной жизни',
#   'year': 1896},
#  'stanyukovich.mrachnyy_shturman.txt': {'filename': 'stanyukovich.mrachnyy_shturman.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Мрачный штурман',
#   'year': 1893},
#  'stanyukovich.nyanka.txt': {'filename': 'stanyukovich.nyanka.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Нянька',
#   'year': 1901},
#  'stanyukovich.passazhirka.txt': {'filename': 'stanyukovich.passazhirka.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Пассажирка',
#   'year': 1893},
#  'stanyukovich.pokhozhdeniya_odnogo_blagonamerennogo.txt': {'filename': 'stanyukovich.pokhozhdeniya_odnogo_blagonamerennogo.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Похождения одного благонамеренного',
#   'year': 1879},
#  'stanyukovich.pokhozhdeniya_odnogo_matrosa.txt': {'filename': 'stanyukovich.pokhozhdeniya_odnogo_matrosa.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Похождения одного матроса',
#   'year': 1913},
#  'stanyukovich.ravnodushnyye.txt': {'filename': 'stanyukovich.ravnodushnyye.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Равнодушные',
#   'year': 1907},
#  'stanyukovich.v_mutnoy_vode.txt': {'filename': 'stanyukovich.v_mutnoy_vode.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'В мутной воде',
#   'year': 1874},
#  'stanyukovich.vasiliy_ivanovich.txt': {'filename': 'stanyukovich.vasiliy_ivanovich.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Василий Иванович',
#   'year': 1895},
#  'stanyukovich.vokrug_sveta_na_korshune.txt': {'filename': 'stanyukovich.vokrug_sveta_na_korshune.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Вокруг света на Коршуне',
#   'year': 1896},
#  'stanyukovich.zhenitba_pinegina.txt': {'filename': 'stanyukovich.zhenitba_pinegina.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Женитьба Пинегина',
#   'year': 1897},
#  'stanyukovich.zhretsy.txt': {'filename': 'stanyukovich.zhretsy.txt',
#   'author': 'Станюкович, Константин Михайлович',
#   'title': 'Жрецы',
#   'year': 1907},
#  'starostin.nashe_schastie.txt': {'filename': 'starostin.nashe_schastie.txt',
#   'author': 'Старостин, Василий Григорьевич',
#   'title': 'Наше счастие',
#   'year': 1901},
#  'starostin.pokhozhdeniya_seminarista_khlopova.txt': {'filename': 'starostin.pokhozhdeniya_seminarista_khlopova.txt',
#   'author': 'Старостин, Василий Григорьевич',
#   'title': 'Похождения семинариста Хлопова',
#   'year': 1901},
#  'starostin.poslednyaya.txt': {'filename': 'starostin.poslednyaya.txt',
#   'author': 'Старостин, Василий Григорьевич',
#   'title': 'Последняя',
#   'year': 1901},
#  'sukhonin.na_rubezhe_stoletiy.txt': {'filename': 'sukhonin.na_rubezhe_stoletiy.txt',
#   'author': 'Сухонин, Петр Петрович',
#   'title': 'На рубеже столетий',
#   'year': 1884},
#  'tan_bogoraz.krivonogiy.txt': {'filename': 'tan_bogoraz.krivonogiy.txt',
#   'author': 'Богораз, Владимир Германович',
#   'title': 'Кривоногий',
#   'year': 1896},
#  'tan_bogoraz.na_reke_rosomashyey.txt': {'filename': 'tan_bogoraz.na_reke_rosomashyey.txt',
#   'author': 'Богораз, Владимир Германович',
#   'title': 'На реке Росомашьей',
#   'year': 1898},
#  'teleshov.na_troykakh.txt': {'filename': 'teleshov.na_troykakh.txt',
#   'author': 'Телешов, Николай Дмитриевич',
#   'title': 'На тройках',
#   'year': 1895},
#  'terpigorev.marfinkino_schastye.txt': {'filename': 'terpigorev.marfinkino_schastye.txt',
#   'author': 'Терпигорев, Сергей Николаевич',
#   'title': 'Марфинькино счастье',
#   'year': 1888},
#  'timofeyev.khudozhnik.txt': {'filename': 'timofeyev.khudozhnik.txt',
#   'author': 'Тимофеев, Алексей Васильевич',
#   'title': 'Художник',
#   'year': 1834},
#  'tolstoy.anna_karenina.txt': {'filename': 'tolstoy.anna_karenina.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Анна Каренина',
#   'year': 1878},
#  'tolstoy.detstvo.txt': {'filename': 'tolstoy.detstvo.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Детство',
#   'year': 1856},
#  'tolstoy.dva_gusara.txt': {'filename': 'tolstoy.dva_gusara.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Два Гусара',
#   'year': 1864},
#  'tolstoy.kazaki.txt': {'filename': 'tolstoy.kazaki.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Казаки',
#   'year': 1864},
#  'tolstoy.kreytserova_sonata.txt': {'filename': 'tolstoy.kreytserova_sonata.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Крейцерова соната',
#   'year': 1890},
#  'tolstoy.otrochestvo.txt': {'filename': 'tolstoy.otrochestvo.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Отрочество',
#   'year': 1856},
#  'tolstoy.polikushka.txt': {'filename': 'tolstoy.polikushka.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Поликушка',
#   'year': 1864},
#  'tolstoy.semeynoye_schastye.txt': {'filename': 'tolstoy.semeynoye_schastye.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Семейное счастье',
#   'year': 1873},
#  'tolstoy.sevastopol_v_avguste_1855_goda.txt': {'filename': 'tolstoy.sevastopol_v_avguste_1855_goda.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Севастополь в августе 1855 года',
#   'year': 1856},
#  'tolstoy.smert_ivana_ilicha.txt': {'filename': 'tolstoy.smert_ivana_ilicha.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Смерть Ивана Ильича',
#   'year': 1886},
#  'tolstoy.voskreseniye.txt': {'filename': 'tolstoy.voskreseniye.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Воскресение',
#   'year': 1899},
#  'tolstoy.voyna_i_mir.txt': {'filename': 'tolstoy.voyna_i_mir.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Война и мир',
#   'year': 1869},
#  'tolstoy.yunost.txt': {'filename': 'tolstoy.yunost.txt',
#   'author': 'Толстой, Лев Николаевич',
#   'title': 'Юность',
#   'year': 1864},
#  'tolstoya.knyaz_serebryanyy.txt': {'filename': 'tolstoya.knyaz_serebryanyy.txt',
#   'author': 'Толстой, Алексей Константинович',
#   'title': 'Князь Серебряный',
#   'year': 1863},
#  'tolstoya.upyr.txt': {'filename': 'tolstoya.upyr.txt',
#   'author': 'Толстой, Алексей Константинович',
#   'title': 'Упырь',
#   'year': 1841},
#  'tur.semeystvo_shalonskikh.txt': {'filename': 'tur.semeystvo_shalonskikh.txt',
#   'author': 'Салиас-де-Турнемир, Елизавета Васильевна',
#   'title': 'Семейство Шалонских',
#   'year': 1880},
#  'tur.starushka.txt': {'filename': 'tur.starushka.txt',
#   'author': 'Салиас-де-Турнемир, Елизавета Васильевна',
#   'title': 'Старушка',
#   'year': 1859},
#  'turgenev.dnevnik_lishnego_cheloveka.txt': {'filename': 'turgenev.dnevnik_lishnego_cheloveka.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Дневник лишнего человека',
#   'year': 1850},
#  'turgenev.dva_priyatelya.txt': {'filename': 'turgenev.dva_priyatelya.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Два приятеля',
#   'year': 1860},
#  'turgenev.dvoryanskoye_gnezdo.txt': {'filename': 'turgenev.dvoryanskoye_gnezdo.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Дворянское гнездо',
#   'year': 1859},
#  'turgenev.dym.txt': {'filename': 'turgenev.dym.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Дым',
#   'year': 1867},
#  'turgenev.klara_milich.txt': {'filename': 'turgenev.klara_milich.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Клара Милич (После смерти)',
#   'year': 1883},
#  'turgenev.nakanune.txt': {'filename': 'turgenev.nakanune.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Накануне',
#   'year': 1860},
#  'turgenev.neschastnaya.txt': {'filename': 'turgenev.neschastnaya.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Несчастная',
#   'year': 1869},
#  'turgenev.nov.txt': {'filename': 'turgenev.nov.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Новь',
#   'year': 1877},
#  'turgenev.ottsy_i_deti.txt': {'filename': 'turgenev.ottsy_i_deti.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Отцы и дети',
#   'year': 1862},
#  'turgenev.pervaya_lyubov.txt': {'filename': 'turgenev.pervaya_lyubov.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Первая любовь',
#   'year': 1860},
#  'turgenev.postoyalyy_dvor.txt': {'filename': 'turgenev.postoyalyy_dvor.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Постоялый двор',
#   'year': 1856},
#  'turgenev.rudin.txt': {'filename': 'turgenev.rudin.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Рудин',
#   'year': 1856},
#  'turgenev.stepnoy_korol_lir.txt': {'filename': 'turgenev.stepnoy_korol_lir.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Степной король Лир',
#   'year': 1873},
#  'turgenev.veshniye_vody.txt': {'filename': 'turgenev.veshniye_vody.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Вешние воды',
#   'year': 1873},
#  'turgenev.zatishye.txt': {'filename': 'turgenev.zatishye.txt',
#   'author': 'Тургенев, Иван Сергеевич',
#   'title': 'Затишье',
#   'year': 1856},
#  'uspenskiyg.nravy_rasteryayevoy_ulitsy.txt': {'filename': 'uspenskiyg.nravy_rasteryayevoy_ulitsy.txt',
#   'author': 'Успенский, Глеб Иванович',
#   'title': 'Нравы растеряевой улицы',
#   'year': 1866},
#  'veltman.koshchey_bessmertnyy.txt': {'filename': 'veltman.koshchey_bessmertnyy.txt',
#   'author': 'Вельтман, Александр Фомич',
#   'title': 'Кощей бессмертный',
#   'year': 1833},
#  'veltman.priklyucheniya_pocherpnutyye_iz_morya_zhiteyskogo.txt': {'filename': 'veltman.priklyucheniya_pocherpnutyye_iz_morya_zhiteyskogo.txt',
#   'author': 'Вельтман, Александр Фомич',
#   'title': 'Приключения почерпнутые из моря житейского',
#   'year': 1848},
#  'veltman.rayna_korolevna_bolgarskaya.txt': {'filename': 'veltman.rayna_korolevna_bolgarskaya.txt',
#   'author': 'Вельтман, Александр Фомич',
#   'title': 'Райна королевна Болгарская',
#   'year': 1843},
#  'veltman.strannik.txt': {'filename': 'veltman.strannik.txt',
#   'author': 'Вельтман, Александр Фомич',
#   'title': 'Странник',
#   'year': 1832},
#  'veltman.svetoslavich_vrazhiy_pitomets.txt': {'filename': 'veltman.svetoslavich_vrazhiy_pitomets.txt',
#   'author': 'Вельтман, Александр Фомич',
#   'title': 'Светославич вражий питомец',
#   'year': 1835},
#  'veltmane.im_prividelsya_son.txt': {'filename': 'veltmane.im_prividelsya_son.txt',
#   'author': 'Вельтман (Кубе), Елена Ивановна',
#   'title': 'Им привидeлся сон',
#   'year': 1846},
#  'veresayev.bez_dorogi.txt': {'filename': 'veresayev.bez_dorogi.txt',
#   'author': 'Вересаев, Викентий Викентьевич',
#   'title': 'Без дороги',
#   'year': 1898},
#  'veresayev.povetriye.txt': {'filename': 'veresayev.povetriye.txt',
#   'author': 'Вересаев, Викентий Викентьевич',
#   'title': 'Поветрие',
#   'year': 1898},
#  'vereshchagin.literator.txt': {'filename': 'vereshchagin.literator.txt',
#   'author': 'Верещагин, Василий Васильевич',
#   'title': 'Литератор',
#   'year': 1894},
#  'veselitskaya.mimochka.txt': {'filename': 'veselitskaya.mimochka.txt',
#   'author': 'Веселитская, Лидия Ивановна',
#   'title': 'Мимочка',
#   'year': 1892},
#  'volkonskiy.brat_gertsoga.txt': {'filename': 'volkonskiy.brat_gertsoga.txt',
#   'author': 'Волконский, Михаил Николаевич',
#   'title': 'Брат герцога',
#   'year': 1900},
#  'volkonskiy.koltso_imperatritsy.txt': {'filename': 'volkonskiy.koltso_imperatritsy.txt',
#   'author': 'Волконский, Михаил Николаевич',
#   'title': 'Кольцо императрицы',
#   'year': 1902},
#  'vonlyarlyarskiy.bolshaya_barynya.txt': {'filename': 'vonlyarlyarskiy.bolshaya_barynya.txt',
#   'author': 'Вонлярлярский, Василий Александрович',
#   'title': 'Большая барыня',
#   'year': 1852},
#  'vonlyarlyarskiy.noch_na_28_ye_sentyabrya.txt': {'filename': 'vonlyarlyarskiy.noch_na_28_ye_sentyabrya.txt',
#   'author': 'Вонлярлярский, Василий Александрович',
#   'title': 'Ночь на 28-е сентября',
#   'year': 1853},
#  'yakubovich.v_mire_otverzhennykh.txt': {'filename': 'yakubovich.v_mire_otverzhennykh.txt',
#   'author': 'Якубович, Пётр Филиппович',
#   'title': 'В мире отверженных',
#   'year': 1899},
#  'yasinskiy.bunt_ivana_ivanycha.txt': {'filename': 'yasinskiy.bunt_ivana_ivanycha.txt',
#   'author': 'Ясинский, Иероним Иеронимович',
#   'title': 'Бунт Ивана Иваныча',
#   'year': 1886},
#  'yasinskiy.uchitel.txt': {'filename': 'yasinskiy.uchitel.txt',
#   'author': 'Ясинский, Иероним Иеронимович',
#   'title': 'Учитель',
#   'year': 1888},
#  'yasinskiy.verochka.txt': {'filename': 'yasinskiy.verochka.txt',
#   'author': 'Ясинский, Иероним Иеронимович',
#   'title': 'Верочка',
#   'year': 1887},
#  'yelpatyevskiy.ocherki_sibiri.txt': {'filename': 'yelpatyevskiy.ocherki_sibiri.txt',
#   'author': 'Елпатьевский, Сергей Яковлевич',
#   'title': 'Очерки Сибири',
#   'year': 1897},
#  'yermolova.v_svete_i_doma.txt': {'filename': 'yermolova.v_svete_i_doma.txt',
#   'author': 'Ермолова, Екатерина Петровна',
#   'title': 'В свете и дома',
#   'year': 1856},
#  'yurkovskiy.zaklyuchennyy_n_10.txt': {'filename': 'yurkovskiy.zaklyuchennyy_n_10.txt',
#   'author': 'Юрковский, Фёдор Николаевич',
#   'title': 'Булгаков (Заключенный N 10)',
#   'year': 1933},
#  'zagoskin.askoldova_mogila.txt': {'filename': 'zagoskin.askoldova_mogila.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Аскольдова могила: Повесть времен Владимира Первого',
#   'year': 1833},
#  'zagoskin.brynskiy_les.txt': {'filename': 'zagoskin.brynskiy_les.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Брынский лес',
#   'year': 1846},
#  'zagoskin.iskusitel.txt': {'filename': 'zagoskin.iskusitel.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Искуситель',
#   'year': 1838},
#  'zagoskin.moskva_i_moskvichi.txt': {'filename': 'zagoskin.moskva_i_moskvichi.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Москва и москвичи: Записки Богдана Ильича Бельского, издаваемые М.Н. Загоскиным',
#   'year': 1850},
#  'zagoskin.roslavlev_ili_russkiye_v_1812_godu.txt': {'filename': 'zagoskin.roslavlev_ili_russkiye_v_1812_godu.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Рославлев, или Русские в 1812 году',
#   'year': 1831},
#  'zagoskin.russkiye_v_nachale_osmnadtsatogo_stoletiya.txt': {'filename': 'zagoskin.russkiye_v_nachale_osmnadtsatogo_stoletiya.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Русские в начале осьмнадцатого столетия',
#   'year': 1889},
#  'zagoskin.yuriy_miloslavskiy_ili_russkiye_v_1612_godu.txt': {'filename': 'zagoskin.yuriy_miloslavskiy_ili_russkiye_v_1612_godu.txt',
#   'author': 'Загоскин, Михаил Николаевич',
#   'title': 'Юрий Милославский или Русские в 1612 году',
#   'year': 1829},
#  'zasodimskiy.temnyye_sily.txt': {'filename': 'zasodimskiy.temnyye_sily.txt',
#   'author': 'Засодимский, Павел Владимирович',
#   'title': 'Темные силы',
#   'year': 1876},
#  'zhadovskaya.otstalaya.txt': {'filename': 'zhadovskaya.otstalaya.txt',
#   'author': 'Жадовская, Юлия Валериановна',
#   'title': 'Отсталая',
#   'year': 1861},
#  'zhadovskaya.v_storone_ot_bolshogo_sveta.txt': {'filename': 'zhadovskaya.v_storone_ot_bolshogo_sveta.txt',
#   'author': 'Жадовская, Юлия Валериановна',
#   'title': 'В стороне от большого света',
#   'year': 1857},
#  'zhelikhovskaya.nad_puchinoy.txt': {'filename': 'zhelikhovskaya.nad_puchinoy.txt',
#   'author': 'Желиховская (Ган), Вера Петровна',
#   'title': 'Над пучиной',
#   'year': 1899},
#  'zhelikhovskaya.podrugi.txt': {'filename': 'zhelikhovskaya.podrugi.txt',
#   'author': 'Желиховская (Ган), Вера Петровна',
#   'title': 'Подруги',
#   'year': 1902},
#  'zhukova.dacha_na_petergofskoy_doroge.txt': {'filename': 'zhukova.dacha_na_petergofskoy_doroge.txt',
#   'author': 'Жукова (Зевакина), Мария Семеновна',
#   'title': 'Дача на Петергофской дороге',
#   'year': 1845},
#  'zlatovratskiy.krestyane_prisyazhnyye.txt': {'filename': 'zlatovratskiy.krestyane_prisyazhnyye.txt',
#   'author': 'Златовратский, Николай Николаевич',
#   'title': 'Крестьяне-присяжные',
#   'year': 1875},
#  'zlatovratskiy.zolotyye_serdtsa.txt': {'filename': 'zlatovratskiy.zolotyye_serdtsa.txt',
#   'author': 'Златовратский, Николай Николаевич',
#   'title': 'Золотые сердца',
#   'year': 1879},
#  'zotov.dva_brata_ili_moskva_v_1812_godu.txt': {'filename': 'zotov.dva_brata_ili_moskva_v_1812_godu.txt',
#   'author': 'Зотов, Рафаил  Михайлович',
#   'title': 'Два брата или Москва в 1812 году',
#   'year': 1850},
#  'zotov.tainstvennyy_monakh.txt': {'filename': 'zotov.tainstvennyy_monakh.txt',
#   'author': 'Зотов, Рафаил  Михайлович',
#   'title': 'Таинственный монах',
#   'year': 1834}}

# %%
book_entities['pretty_author'] = book_entities.book.apply(lambda book: metadata_dict[book]['author'])
book_entities['pretty_title'] = book_entities.book.apply(lambda book: metadata_dict[book]['title'])
book_entities['pretty_year'] = book_entities.book.apply(lambda book: metadata_dict[book]['year'])
book_entities
# Out:
#    norm_surn                                           sentence  \
# 0   павлищев  -- Да, господин Павлищев, который меня там сод...
# 1    епанчин  -- Да, господин Павлищев, который меня там сод...
# 2    епанчин  -- Узелок ваш все-таки имеет некоторое значени...
# 3    епанчин  -- Узелок ваш все-таки имеет некоторое значени...
# 4   павлищев  Гм... генерала же Епанчина знаем-с, собственно...
# ..       ...                                                ...
# 55       жук                            Жук поместился в ногах.
# 56  дмитриев        Она крепко прижалась к Дмитриевой поддевке.
# 57       жук  Жука некуда было взять; тетя ни за что не позв...
# 58       жук  Бедный Жук лаял, бегал вокруг коляски; Аксюша ...
# 59  зиночкин       Лева наотрез отказался от Зиночкиных конфет.
#
#                                     book              author  sentiment_class  \
# 0                 dostoyevskiy.idiot.txt        dostoyevskiy                0
# 1                 dostoyevskiy.idiot.txt        dostoyevskiy                0
# 2                 dostoyevskiy.idiot.txt        dostoyevskiy                0
# 3                 dostoyevskiy.idiot.txt        dostoyevskiy                0
# 4                 dostoyevskiy.idiot.txt        dostoyevskiy                0
# ..                                   ...                 ...              ...
# 55  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova                0
# 56  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova                0
# 57  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova                0
# 58  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova                0
# 59  maklakova_nelidova.devochka_lida.txt  maklakova_nelidova                0
#
#                              pretty_author  pretty_title  pretty_year
# 0            Достоевский, Фёдор Михайлович         Идиот         1874
# 1            Достоевский, Фёдор Михайлович         Идиот         1874
# 2            Достоевский, Фёдор Михайлович         Идиот         1874
# 3            Достоевский, Фёдор Михайлович         Идиот         1874
# 4            Достоевский, Фёдор Михайлович         Идиот         1874
# ..                                     ...           ...          ...
# 55  Маклакова (Королёва), Лидия Филипповна  Девочка Лида         1875
# 56  Маклакова (Королёва), Лидия Филипповна  Девочка Лида         1875
# 57  Маклакова (Королёва), Лидия Филипповна  Девочка Лида         1875
# 58  Маклакова (Королёва), Лидия Филипповна  Девочка Лида         1875
# 59  Маклакова (Королёва), Лидия Филипповна  Девочка Лида         1875
#
# [202146 rows x 8 columns]
